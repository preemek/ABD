# %%
#3.1
import matplotlib.pyplot as plt
import numpy as np


x = np.linspace(-1,1,100)


y = x**2


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y, 'r', label = 'y=x^2+5')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc='upper left')

# show the plot
plt.show()

# %%
#3.2
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-6,6,100)


y = x**2


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y, 'r', label = 'y=x^2+5')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc='upper left')

# show the plot
plt.show()

# %%
#3.3
import matplotlib.pyplot as plt
import numpy as np


x = np.linspace(0,5,100)


y = x**2


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y, 'r', label = 'y=x^2+5')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc='upper left')

# show the plot
plt.show()

# %%
#4
import pandas as pd
df = pd.DataFrame(np.array([['Przemek', 'Mysliwiec', 22, 'man'],
                          ['Anna', 'Lop', 99, 'women'],
                          ['Wojciech', 'Krupa', 20, 'man'],
                          ['Tomek', 'Bok', 40, 'man'],
                          ['Klaudia', 'Trela', 50, 'women']]), 
                 columns = ['name', 'surname', 'age', 'sex'])

print(df)
# Out:
#        name    surname age    sex
# 0   Przemek  Mysliwiec  22    man
# 1      Anna        Lop  99  women
# 2  Wojciech      Krupa  20    man
# 3     Tomek        Bok  40    man
# 4   Klaudia      Trela  50  women
